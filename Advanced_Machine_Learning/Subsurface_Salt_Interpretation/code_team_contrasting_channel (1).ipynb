# %% [markdown]
# # Improving Below Ground Salt Identification

# %%
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import tensorflow as tf

# from tqdm import tqdm_notebook, tnrange
# from itertools import chain
# from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
# from skimage.morphology import label # Why doesn't this important work for me? - Brandt

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras import backend as K

# from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing.image import load_img

from pathlib import Path
from sklearn.model_selection import train_test_split

#tf.cast(my_tensor, tf.int32) 
# warnings.filterwarnings("ignore")

# %% [markdown]
# First, we need to specifiy the file paths to our data:

# %%
#path_data = Path() / 'competition_data' # Root data folder
path_test_images =  './test/images/' # Directory containing the test images
path_train_images = './train/images/' # Directory containing the training images
path_train_masks = './train/masks/' # Directory containing the training masks

# %% [markdown]
# Load the raw data csv files and clean them up a bit:

# %%
# 'Depths.csv' contains all of the image ids - train and test -  along with the depth where the image was taken 
depth_data = pd.read_csv('depths.csv', index_col='id')
depth_data.columns = ['depth'] # Rename the column 'z' to 'depth' so its easier to understand

# 'train.csv' contains all of the image ids in the training set
# It also contains another column called 'rle_mask' which isn't very useful, so we convert it to a new variable to indicate if there is salt in the image
train_data = pd.read_csv('train.csv', index_col='id')
train_data['contains_salt'] = ~train_data['rle_mask'].isna()
train_data.drop(columns='rle_mask',inplace=True)

# Merge all of the info together so that we now have training and test data frames
train_df = train_data.merge(depth_data,left_index=True, right_index=True)
test_df = depth_data[~depth_data.index.isin(train_df.index)]

train_df.head()
# Out:
#             contains_salt  depth
# id
# 2c45b152f1           True    312
# 3cb59a4fdc           True    603
# e185ab5dc1           True    687
# c78c89577c           True    236
# 6306dd3a8e           True    805

# %% [markdown]
# We create some helper functions for working with the images:
#
# Note: I think we have to return this as a 3d array because thats how the convolutions expect it to be. Not positive tho

# %%
def get_img_by_id(id:str, as_array:bool=True):
    """Returns a 101 x 101 numpy array of the image by default. If 'as_array' = False then it will return an image pillow object"""
    if id in train_df.index:
        img =  load_img(path_train_images + id + '.png')
    elif id in test_df.index:
        img = load_img(path_test_images + id +  '.png')
    else:
        raise Exception(f'"{id}" is not a valid id you goon!!!')

    if as_array:
        # Return the image as a 3d array with one channel. We don't need the 2&3 channels because this is a grayscale image and they are identical
        return np.array(img)[:,:,:1]
    else:
        return img


def get_mask_by_id(id:str, as_array:bool=True):
    """Same as above, just with the masks of training images"""
    img = load_img(path_train_masks + id + '.png')
    if as_array:
        # Return the image as a 2d array. We don't need the 2&3 channels because this is a grayscale image and they are identical
        return np.array(img)[:,:,:1]
    else:
        return img

# %%
#get_img_by_id(train_df.index[0])

# %% [markdown]
# Now we can visualize a few examples from the training set. Below is displayed several example seismic images, with their accompanying salt idenfitification masks placed adjacent.

# %% [markdown]
# ### Put Masks side by side instead of on top??

# %%
imgs_to_show = 18
num_rows = 3; num_cols = 6
sample_training_ids = train_df.index[:imgs_to_show]

fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols,  figsize=(20,8))

for i, img_id in enumerate(sample_training_ids):
    # Get the correct axis based on how many total rows and columns are in the figure and the current index
    ax = axs[int(i/num_cols), i % num_cols] 
    ax.imshow(get_img_by_id(img_id),cmap='Greys')
#     ax.imshow(get_mask_by_id(img_id),alpha=.35,cmap='Purples')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    # ax.title.set_text(f'{img_id}')

plt.suptitle('Sample Images',fontsize=20);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-dd1766386e3b> in <module>
#       8     # Get the correct axis based on how many total rows and columns are in the figure and the current index
#       9     ax = axs[int(i/num_cols), i % num_cols]
# ---> 10     ax.imshow(get_img_by_id(img_id),cmap='Greys')
#      11 #     ax.imshow(get_mask_by_id(img_id),alpha=.35,cmap='Purples')
#      12     ax.axes.get_xaxis().set_visible(False)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (101, 101, 1) for image data

# %%
imgs_to_show = 18
num_rows = 3; num_cols = 6
sample_training_ids = train_df.index[:imgs_to_show]

fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols,  figsize=(20,8))

for i, img_id in enumerate(sample_training_ids):
    # Get the correct axis based on how many total rows and columns are in the figure and the current index
    ax = axs[int(i/num_cols), i % num_cols] 
#     ax.imshow(get_img_by_id(img_id),cmap='Greys')
    ax.imshow(get_mask_by_id(img_id),cmap='Purples')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    # ax.title.set_text(f'{img_id}')

plt.suptitle('Sample Images',fontsize=20);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-33282429b435> in <module>
#       9     ax = axs[int(i/num_cols), i % num_cols]
#      10 #     ax.imshow(get_img_by_id(img_id),cmap='Greys')
# ---> 11     ax.imshow(get_mask_by_id(img_id),cmap='Purples')
#      12     ax.axes.get_xaxis().set_visible(False)
#      13     ax.axes.get_yaxis().set_visible(False)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (101, 101, 1) for image data

# %% [markdown]
# ## Prepare Data for Model

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.cast(y_pred > t, tf.int32)
        score, up_opt = tf.compat.v1.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
img_size_needed = 128

# %% [markdown]
# Load in all of the images and their masks as numpy arrays:

# %%
X_all = np.array([get_img_by_id(id) for id in train_df.index])
Y_all = np.array([get_mask_by_id(id) for id in train_df.index])

# %% [markdown]
# Messy cell below,  but it's vectorized for performance purposes
#
# Notes:
# * Explain why np. floor and converting to bool

# %%
X_all_resized = np.array([np.floor(resize(img, (img_size_needed, img_size_needed, 1), mode='constant', preserve_range=True)) for img in X_all])
Y_all_resized = np.array([np.array(resize(img, (img_size_needed, img_size_needed, 1), mode='constant', preserve_range=True),dtype=bool) for img in Y_all])

# %% [markdown]
# Split the training into train and validaiton sets.

# %%
X_train, X_test, Y_train, Y_test  = train_test_split(X_all_resized, Y_all_resized,train_size=3500, random_state=42)

# %% [markdown]
# Now add in some extra training images by flipping, and rotating the training set. Shuffle again just because.

# %%
X_ud_flipped = [np.flipud(img) for img in X_train]
X_lr_flipped = [np.fliplr(img) for img in X_train]
X_rotated = [np.rot90(img) for img in X_train]

Y_ud_flipped = [np.flipud(img) for img in Y_train]
Y_lr_flipped = [np.fliplr(img) for img in Y_train]
Y_rotated = [np.rot90(img) for img in Y_train]

X_train = np.concatenate([X_train,X_ud_flipped,X_lr_flipped,X_rotated])
Y_train = np.concatenate([Y_train, Y_ud_flipped, Y_lr_flipped,Y_rotated])

#Shuffle, just to make sure we didn't accidently introduce anything weird.
shuffled_indices = np.random.permutation(len(X_train))
X_train = X_train[shuffled_indices]
Y_train = Y_train[shuffled_indices]

# %% [markdown]
# ### Show examples images of the flips and rotations and stuff here so that we can validate that none of the above manipulations screwed up the data

# %% [markdown]
# ## Model Building
#
# The Keras functional API is pretty intuitive and easy to use. The ouput of each function is another function, which allows you to pass the new layer as an input to the current layer.
#
# ### Model Notes:
# * Need to be able to explain all of the parameters...
# * padding = same because we want to keep image size same
# * Why do we need to divide by 255 again?
# * Kernal Initializer, should we use something else instead of default. Youtube guy used 'he_normal'
# * The Unet paper and youtube guy start with 16 filters on the first convolution, but we start with 8
# * Convo2d Transpose has inverse affect of pooling
# * In the ecnoding process, image gets smaller because of pooling, but at the same time we are doubling the amount of filters each time?
# * Shouldn't the max pooling reduce the image pixels by a factor 4 instead of 2?
# * Add dropout in between certain layers?
# * We should examine the number of filters for everything really. We should probably have a reason, if it is not the exact same as Unet

# %% [markdown]
# <iframe src="https://drive.google.com/file/d/1UXcjA486sL2luT4aUJq97zTSUOOIlo60/preview" width="640" height="480" allow="autoplay"></iframe>

# %%
from keras import backend as K

# %%
IMG_WIDTH, IMG_HEIGHT = 128, 128

# %%
X_train.shape
# Out:
# (14000, 128, 128, 1)

# %%
import cv2
import sklearn.preprocessing
sobelxy = []
i=0
for img in X_train:
    sobel_out = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)
    sobel_norm = sklearn.preprocessing.normalize(sobel_out)
    sobelxy.append((sobel_norm + 1)/2)
    i+=1

# %%
X_train_sobel = np.array(sobelxy).reshape(14000, 128, 128, 1)
X_train_channel = np.concatenate((X_train,X_train_sobel), axis =3)
X_train_channel.shape
# Out:
# (14000, 128, 128, 2)

# %%
sobelxy_test = []
i=0
for img in X_test:
    sobel_out = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)
    sobel_norm = sklearn.preprocessing.normalize(sobel_out)
    sobelxy_test.append((sobel_norm + 1)/2)
    i+=1
X_test_sobel = np.array(sobelxy_test).reshape(500, 128, 128, 1)
X_test_channel = np.concatenate((X_test,X_test_sobel), axis =3)
X_test_channel.shape
# Out:
# (500, 128, 128, 2)

# %%
# Number of inputs equals the number of pixels in our images * number of channels, which in this case is 1 because the images are greyscale.
# from keras.layers.convolutional import Conv3d, Conv3dTranspose
inputs = Input((IMG_WIDTH, IMG_HEIGHT, 1))

# Layer to convert the pixels to 0-1 scales which is expected from later on layers
s = Lambda(lambda img_pixels: img_pixels / 255) (inputs)


c1 = Conv2D(filters = 8, kernel_size=(3,3), activation='relu', padding='same') (s)
c1 = Conv2D(filters = 8, kernel_size=(3,3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(filters = 16, kernel_size=(3,3), activation='relu', padding='same') (p1)
c2 = Conv2D(filters = 16, kernel_size=(3,3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D(pool_size=(2, 2)) (c2)

c3 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same') (p2)
c3 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D(pool_size=(2, 2)) (c3)

c4 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same') (p3)
c4 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same') (p4)
c5 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(filters=64, kernel_size=(2,2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same') (u6)
c6 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(filters=32, kernel_size=(2,2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same') (u7)
c7 = Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(filters=16, kernel_size=(2,2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same') (u8)
c8 = Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(filters=8, kernel_size=(2,2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same') (u9)
c9 = Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same') (c9)

# Final output is sigmoid so that we get a probability for each pizel!
outputs = Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid') (c9)

unet_model = Model(inputs=[inputs], outputs=[outputs])
unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou, 'accuracy'])
#unet_model = Model(inputs=[inputs], outputs=[outputs])
#unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.MeanIoU(num_classes = 2),'accuracy'])

# %%
unet_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 128, 128, 1)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 128, 128, 8)  80          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 128, 128, 8)  584         conv2d_77[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 64, 64, 8)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 64, 16)   1168        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 16)   2320        conv2d_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 32, 16)   0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 32)   0           conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 64)   18496       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 128)    73856       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 128)    147584      conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 16, 16, 64)   32832       conv2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_17[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 64)   73792       concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_18[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_19[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 64, 64, 16)   2320        conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 128, 128, 8)  520         conv2d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_20[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 128, 128, 8)  1160        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 128, 128, 8)  584         conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 128, 128, 1)  9           conv2d_94[0][0]
# ==================================================================================================
# Total params: 485,673
# Trainable params: 485,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 30
batch_size = 10 # Use 10 images in each batch

earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('salty_unet_model_contrasted_channel.h5', verbose=1, save_best_only=True)
results = unet_model.fit(X_train_channel, Y_train,validation_data = (X_test_channel,Y_test) ,batch_size=batch_size, epochs=epochs, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 14000 samples, validate on 500 samples
# Epoch 1/30
# 14000/14000 [==============================] - 271s 19ms/step - loss: 0.5386 - mean_io_u_1: 0.3735 - accuracy: 0.7581 - val_loss: 0.4243 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8175
#
# Epoch 00001: val_loss improved from inf to 0.42435, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 2/30
# 14000/14000 [==============================] - 264s 19ms/step - loss: 0.3878 - mean_io_u_1: 0.3738 - accuracy: 0.8528 - val_loss: 0.3501 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8709
#
# Epoch 00002: val_loss improved from 0.42435 to 0.35011, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 3/30
# 14000/14000 [==============================] - 265s 19ms/step - loss: 0.3455 - mean_io_u_1: 0.3739 - accuracy: 0.8731 - val_loss: 0.3061 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8851
#
# Epoch 00003: val_loss improved from 0.35011 to 0.30611, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 4/30
# 14000/14000 [==============================] - 261s 19ms/step - loss: 0.3232 - mean_io_u_1: 0.3740 - accuracy: 0.8815 - val_loss: 0.3008 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8897
#
# Epoch 00004: val_loss improved from 0.30611 to 0.30082, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 5/30
# 14000/14000 [==============================] - 261s 19ms/step - loss: 0.3084 - mean_io_u_1: 0.3740 - accuracy: 0.8865 - val_loss: 0.3133 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8790
#
# Epoch 00005: val_loss did not improve from 0.30082
# Epoch 6/30
# 14000/14000 [==============================] - 267s 19ms/step - loss: 0.2883 - mean_io_u_1: 0.3740 - accuracy: 0.8949 - val_loss: 0.2641 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9000
#
# Epoch 00006: val_loss improved from 0.30082 to 0.26408, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 7/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2581 - mean_io_u_1: 0.3739 - accuracy: 0.9068 - val_loss: 0.2557 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9078
#
# Epoch 00007: val_loss improved from 0.26408 to 0.25575, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 8/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2560 - mean_io_u_1: 0.3741 - accuracy: 0.9069 - val_loss: 0.2653 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9062
#
# Epoch 00008: val_loss did not improve from 0.25575
# Epoch 9/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2492 - mean_io_u_1: 0.3739 - accuracy: 0.9085 - val_loss: 0.2669 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8971
#
# Epoch 00009: val_loss did not improve from 0.25575
# Epoch 10/30
# 14000/14000 [==============================] - 267s 19ms/step - loss: 0.2370 - mean_io_u_1: 0.3740 - accuracy: 0.9128 - val_loss: 0.2325 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9103
#
# Epoch 00010: val_loss improved from 0.25575 to 0.23254, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 11/30
# 14000/14000 [==============================] - 267s 19ms/step - loss: 0.2300 - mean_io_u_1: 0.3739 - accuracy: 0.9150 - val_loss: 0.2259 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9148
#
# Epoch 00011: val_loss improved from 0.23254 to 0.22587, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 12/30
# 14000/14000 [==============================] - 264s 19ms/step - loss: 0.2226 - mean_io_u_1: 0.3740 - accuracy: 0.9173 - val_loss: 0.2304 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9123
#
# Epoch 00012: val_loss did not improve from 0.22587
# Epoch 13/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2313 - mean_io_u_1: 0.3740 - accuracy: 0.9139 - val_loss: 0.2753 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.8971
#
# Epoch 00013: val_loss did not improve from 0.22587
# Epoch 14/30
# 14000/14000 [==============================] - 268s 19ms/step - loss: 0.2159 - mean_io_u_1: 0.3739 - accuracy: 0.9195 - val_loss: 0.2275 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9161
#
# Epoch 00014: val_loss did not improve from 0.22587
# Epoch 15/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2112 - mean_io_u_1: 0.3740 - accuracy: 0.9213 - val_loss: 0.2071 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9192
#
# Epoch 00015: val_loss improved from 0.22587 to 0.20711, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 16/30
# 14000/14000 [==============================] - 263s 19ms/step - loss: 0.2170 - mean_io_u_1: 0.3740 - accuracy: 0.9190 - val_loss: 0.2430 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9128
#
# Epoch 00016: val_loss did not improve from 0.20711
# Epoch 17/30
# 14000/14000 [==============================] - 265s 19ms/step - loss: 0.2093 - mean_io_u_1: 0.3739 - accuracy: 0.9217 - val_loss: 0.2177 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9207
#
# Epoch 00017: val_loss did not improve from 0.20711
# Epoch 18/30
# 14000/14000 [==============================] - 265s 19ms/step - loss: 0.2062 - mean_io_u_1: 0.3739 - accuracy: 0.9231 - val_loss: 0.2239 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9182
#
# Epoch 00018: val_loss did not improve from 0.20711
# Epoch 19/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2019 - mean_io_u_1: 0.3740 - accuracy: 0.9244 - val_loss: 0.2004 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9215
#
# Epoch 00019: val_loss improved from 0.20711 to 0.20040, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 20/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.2041 - mean_io_u_1: 0.3739 - accuracy: 0.9235 - val_loss: 0.2312 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9144
#
# Epoch 00020: val_loss did not improve from 0.20040
# Epoch 21/30
# 14000/14000 [==============================] - 265s 19ms/step - loss: 0.1983 - mean_io_u_1: 0.3740 - accuracy: 0.9256 - val_loss: 0.2008 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9228
#
# Epoch 00021: val_loss did not improve from 0.20040
# Epoch 22/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.1968 - mean_io_u_1: 0.3740 - accuracy: 0.9266 - val_loss: 0.2020 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9229
#
# Epoch 00022: val_loss did not improve from 0.20040
# Epoch 23/30
# 14000/14000 [==============================] - 265s 19ms/step - loss: 0.1954 - mean_io_u_1: 0.3740 - accuracy: 0.9265 - val_loss: 0.1923 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9256
#
# Epoch 00023: val_loss improved from 0.20040 to 0.19231, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 24/30
# 14000/14000 [==============================] - 266s 19ms/step - loss: 0.1939 - mean_io_u_1: 0.3740 - accuracy: 0.9274 - val_loss: 0.1881 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9281
#
# Epoch 00024: val_loss improved from 0.19231 to 0.18810, saving model to salty_unet_model_contrasted_channel.h5
# Epoch 25/30
# 14000/14000 [==============================] - 264s 19ms/step - loss: 0.2238 - mean_io_u_1: 0.3739 - accuracy: 0.9156 - val_loss: 0.1978 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9228
#
# Epoch 00025: val_loss did not improve from 0.18810
# Epoch 26/30
# 14000/14000 [==============================] - 272s 19ms/step - loss: 0.1949 - mean_io_u_1: 0.3740 - accuracy: 0.9271 - val_loss: 0.2027 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9239
#
# Epoch 00026: val_loss did not improve from 0.18810
# Epoch 27/30
# 14000/14000 [==============================] - 270s 19ms/step - loss: 0.1917 - mean_io_u_1: 0.3740 - accuracy: 0.9279 - val_loss: 0.2250 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9152
#
# Epoch 00027: val_loss did not improve from 0.18810
# Epoch 28/30
# 14000/14000 [==============================] - 270s 19ms/step - loss: 0.1914 - mean_io_u_1: 0.3740 - accuracy: 0.9281 - val_loss: 0.1920 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9263
#
# Epoch 00028: val_loss did not improve from 0.18810
# Epoch 29/30
# 14000/14000 [==============================] - 264s 19ms/step - loss: 0.1884 - mean_io_u_1: 0.3740 - accuracy: 0.9290 - val_loss: 0.1959 - val_mean_io_u_1: 0.3740 - val_accuracy: 0.9248
#
# Epoch 00029: val_loss did not improve from 0.18810
# Epoch 00029: early stopping

# %%
epochs = 20
batch_size = 10 # Use 10 images in each batch

earlystopper = EarlyStopping(patience=3, verbose=1)
checkpointer = ModelCheckpoint('salty_unet_model_14000_1.h5', verbose=1, save_best_only=True)
results = unet_model.fit(X_train, Y_train,validation_data = (X_test,Y_test) ,batch_size=batch_size, epochs=epochs, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 14000 samples, validate on 500 samples
# Epoch 1/20
# 14000/14000 [==============================] - 292s 21ms/step - loss: 0.4842 - mean_iou: 0.3891 - accuracy: 0.7915 - val_loss: 0.3767 - val_mean_iou: 0.4171 - val_accuracy: 0.8651
#
# Epoch 00001: val_loss improved from inf to 0.37673, saving model to salty_unet_model_14000_1.h5
# Epoch 2/20
# 14000/14000 [==============================] - 292s 21ms/step - loss: 0.3647 - mean_iou: 0.4577 - accuracy: 0.8632 - val_loss: 0.3227 - val_mean_iou: 0.4954 - val_accuracy: 0.8832
#
# Epoch 00002: val_loss improved from 0.37673 to 0.32266, saving model to salty_unet_model_14000_1.h5
# Epoch 3/20
# 14000/14000 [==============================] - 285s 20ms/step - loss: 0.3263 - mean_iou: 0.5213 - accuracy: 0.8825 - val_loss: 0.3157 - val_mean_iou: 0.5442 - val_accuracy: 0.8895
#
# Epoch 00003: val_loss improved from 0.32266 to 0.31572, saving model to salty_unet_model_14000_1.h5
# Epoch 4/20
# 14000/14000 [==============================] - 287s 20ms/step - loss: 0.2920 - mean_iou: 0.5623 - accuracy: 0.8965 - val_loss: 0.2592 - val_mean_iou: 0.5805 - val_accuracy: 0.9081
#
# Epoch 00004: val_loss improved from 0.31572 to 0.25918, saving model to salty_unet_model_14000_1.h5
# Epoch 5/20
# 14000/14000 [==============================] - 291s 21ms/step - loss: 0.2728 - mean_iou: 0.5931 - accuracy: 0.9034 - val_loss: 0.2374 - val_mean_iou: 0.6067 - val_accuracy: 0.9176
#
# Epoch 00005: val_loss improved from 0.25918 to 0.23735, saving model to salty_unet_model_14000_1.h5
# Epoch 6/20
# 14000/14000 [==============================] - 290s 21ms/step - loss: 0.2403 - mean_iou: 0.6187 - accuracy: 0.9151 - val_loss: 0.2422 - val_mean_iou: 0.6296 - val_accuracy: 0.9174
#
# Epoch 00006: val_loss did not improve from 0.23735
# Epoch 7/20
# 14000/14000 [==============================] - 286s 20ms/step - loss: 0.2312 - mean_iou: 0.6392 - accuracy: 0.9174 - val_loss: 0.2381 - val_mean_iou: 0.6469 - val_accuracy: 0.9136
#
# Epoch 00007: val_loss did not improve from 0.23735
# Epoch 8/20
# 14000/14000 [==============================] - 289s 21ms/step - loss: 0.2144 - mean_iou: 0.6546 - accuracy: 0.9228 - val_loss: 0.2297 - val_mean_iou: 0.6619 - val_accuracy: 0.9105
#
# Epoch 00008: val_loss improved from 0.23735 to 0.22975, saving model to salty_unet_model_14000_1.h5
# Epoch 9/20
# 14000/14000 [==============================] - 289s 21ms/step - loss: 0.2032 - mean_iou: 0.6689 - accuracy: 0.9271 - val_loss: 0.2065 - val_mean_iou: 0.6750 - val_accuracy: 0.9223
#
# Epoch 00009: val_loss improved from 0.22975 to 0.20648, saving model to salty_unet_model_14000_1.h5
# Epoch 10/20
# 14000/14000 [==============================] - 290s 21ms/step - loss: 0.1955 - mean_iou: 0.6809 - accuracy: 0.9296 - val_loss: 0.2083 - val_mean_iou: 0.6860 - val_accuracy: 0.9260
#
# Epoch 00010: val_loss did not improve from 0.20648
# Epoch 11/20
# 14000/14000 [==============================] - 293s 21ms/step - loss: 0.1881 - mean_iou: 0.6909 - accuracy: 0.9322 - val_loss: 0.2027 - val_mean_iou: 0.6957 - val_accuracy: 0.9244
#
# Epoch 00011: val_loss improved from 0.20648 to 0.20275, saving model to salty_unet_model_14000_1.h5
# Epoch 12/20
# 14000/14000 [==============================] - 294s 21ms/step - loss: 0.1820 - mean_iou: 0.7001 - accuracy: 0.9340 - val_loss: 0.2005 - val_mean_iou: 0.7041 - val_accuracy: 0.9197
#
# Epoch 00012: val_loss improved from 0.20275 to 0.20053, saving model to salty_unet_model_14000_1.h5
# Epoch 13/20
# 14000/14000 [==============================] - 289s 21ms/step - loss: 0.1745 - mean_iou: 0.7081 - accuracy: 0.9359 - val_loss: 0.1977 - val_mean_iou: 0.7118 - val_accuracy: 0.9282
#
# Epoch 00013: val_loss improved from 0.20053 to 0.19770, saving model to salty_unet_model_14000_1.h5
# Epoch 14/20
# 14000/14000 [==============================] - 283s 20ms/step - loss: 0.1721 - mean_iou: 0.7152 - accuracy: 0.9372 - val_loss: 0.1962 - val_mean_iou: 0.7186 - val_accuracy: 0.9309
#
# Epoch 00014: val_loss improved from 0.19770 to 0.19624, saving model to salty_unet_model_14000_1.h5
# Epoch 15/20
# 14000/14000 [==============================] - 283s 20ms/step - loss: 0.1647 - mean_iou: 0.7218 - accuracy: 0.9399 - val_loss: 0.1781 - val_mean_iou: 0.7248 - val_accuracy: 0.9341
#
# Epoch 00015: val_loss improved from 0.19624 to 0.17813, saving model to salty_unet_model_14000_1.h5
# Epoch 16/20
# 14000/14000 [==============================] - 284s 20ms/step - loss: 0.1608 - mean_iou: 0.7278 - accuracy: 0.9410 - val_loss: 0.1941 - val_mean_iou: 0.7305 - val_accuracy: 0.9322
#
# Epoch 00016: val_loss did not improve from 0.17813
# Epoch 17/20
# 14000/14000 [==============================] - 288s 21ms/step - loss: 0.1546 - mean_iou: 0.7333 - accuracy: 0.9434 - val_loss: 0.1942 - val_mean_iou: 0.7358 - val_accuracy: 0.9271
#
# Epoch 00017: val_loss did not improve from 0.17813
# Epoch 18/20
# 14000/14000 [==============================] - 284s 20ms/step - loss: 0.1523 - mean_iou: 0.7383 - accuracy: 0.9441 - val_loss: 0.1957 - val_mean_iou: 0.7407 - val_accuracy: 0.9310
#
# Epoch 00018: val_loss did not improve from 0.17813
# Epoch 00018: early stopping

# %% [markdown]
# ### Training Results

# %%
history_df = pd.DataFrame(results.history)
history_df
# Out:
#     val_loss  val_mean_iou  val_accuracy      loss  mean_iou  accuracy
# 0   0.376734      0.417120      0.865077  0.484171  0.389057  0.791539
# 1   0.322655      0.495357      0.883197  0.364716  0.457651  0.863246
# 2   0.315717      0.544154      0.889548  0.326264  0.521298  0.882467
# 3   0.259178      0.580545      0.908071  0.292005  0.562282  0.896486
# 4   0.237355      0.606651      0.917576  0.272754  0.593105  0.903424
# 5   0.242163      0.629586      0.917378  0.240318  0.618724  0.915095
# 6   0.238131      0.646914      0.913611  0.231207  0.639171  0.917413
# 7   0.229745      0.661908      0.910486  0.214374  0.654563  0.922767
# 8   0.206481      0.674956      0.922319  0.203178  0.668907  0.927117
# 9   0.208295      0.685992      0.926043  0.195502  0.680914  0.929645
# 10  0.202745      0.695681      0.924360  0.188109  0.690916  0.932244
# 11  0.200527      0.704103      0.919698  0.182026  0.700141  0.934013
# 12  0.197700      0.711813      0.928198  0.174451  0.708067  0.935877
# 13  0.196237      0.718553      0.930902  0.172136  0.715176  0.937235
# 14  0.178135      0.724841      0.934110  0.164653  0.721782  0.939908
# 15  0.194115      0.730516      0.932232  0.160796  0.727771  0.941033
# 16  0.194161      0.735828      0.927088  0.154561  0.733300  0.943365
# 17  0.195712      0.740748      0.931040  0.152346  0.738319  0.944084

# %%
history_df['epoch'] = history_df.index

# %%
import seaborn as sns

sns.lineplot(data = history_df, x='epoch', y = 'val_loss')

# %%
sns.lineplot(data = history_df, x='epoch', y = 'val_mean_iou')

# %%
sns.lineplot(data = history_df, x='epoch', y = 'accuracy')

# %% [markdown]
# ## Predictions

# %% [markdown]
# Now we can load the model without having to retrain it!!!

# %%
# Load Model
unet_model = load_model('salty_unet_model_contrasted_channel.h5')

prob_threshold = .5

# %% [markdown]
# Below needs to be cleaned up quite a bit. I havent' done anything yet with the real 18000 test images

# %%
# Predict on train, val and test

# preds_train = unet_model.predict(X_train, verbose=1)
preds_val = unet_model.predict(X_test_channel, verbose=1)
# preds_test = unet_model.predict(X_test, verbose=1)

# Threshold predictions
# preds_train_t = (preds_train > prob_threshold).astype(np.uint8)
preds_val_t = (preds_val > prob_threshold).astype(np.uint8)
# preds_test_t = (preds_test > prob_threshold).astype(np.uint8)
# Out:
# 16/16 [==============================] - 3s 173ms/step

# %%
preds_val_t.shape
# Out:
# (500, 128, 128, 1)

# %% [markdown]
# Need to figure out how to make this prettier

# %%
imgs_to_show = 30
num_rows = imgs_to_show; num_cols = 3

fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols,  figsize=(10, 3*imgs_to_show))

for i in range(imgs_to_show):
    ax = axs[i,0]
    ax.imshow(X_test[i],cmap='Greys')
    ax.title.set_text(f'Image')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)

    ax = axs[i,1]
    ax.imshow(Y_test[i],cmap='Blues')
    ax.title.set_text(f'Actual Mask')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)

    ax = axs[i,2]
    ax.imshow(preds_val_t[i],cmap='Blues')
    ax.title.set_text(f'Predicted Mask')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)


plt.suptitle('Prediction Images',fontsize=20);
